# %% [markdown]
# <a href="https://colab.research.google.com/github/yuta-nagatake/python-/blob/main/3_1_%E8%BE%9E%E6%9B%B8_(dictionary).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ppap = {'apple' : 3, 'pen' : 5}
ppap
# Out:
# {'apple': 3, 'pen': 5}

# %%
type(ppap)
# Out:
# dict

# %%
ppap = {'apple' : 3, 'pen' : 5}
ppap['apple']
# Out:
# 3

# %%
ppap['orange']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_5884/2828625380.py in <cell line: 0>()
# ----> 1 ppap['orange']
#
# KeyError: 'orange'

# %%
ppap = {'apple' : 3, 'pen' : 5}
ppap['apple'] = 10
ppap['pinapple'] = 7
ppap
# Out:
# {'apple': 10, 'pen': 5, 'pinapple': 7}

# %%
ppap = {'apple': 3, 'pen': 5}
'apple' in ppap
# Out:
# True

# %%
'banana' in ppap
# Out:
# False

# %%
ppap = {'apple': 3, 'pen': 5}
len(ppap)
# Out:
# 2

# %%
ppap = {'apple' : 3, 'pen' : 5}
del ppap['pen']
ppap
# Out:
# {'apple': 3}

# %%
empty_d = {}
empty_d
# Out:
# {}

# %%
ppap = {'apple' : 3, 'pen' : 5}
ppap.clear()
ppap
# Out:
# {}

# %%
ppap = {'apple' : 3, 'pen' : 5}
list(ppap.keys())
# Out:
# ['apple', 'pen']

# %%
list(ppap.values())
# Out:
# [3, 5]

# %%
list(ppap.items())
# Out:
# [('apple', 3), ('pen', 5)]

# %%
ppap = {'apple': 3, 'pen': 5, 'orange': 7}
ppap2 = ppap.copy()
ppap['banana'] = 9
print(ppap)
print(ppap2)
# Out:
# {'apple': 3, 'pen': 5, 'orange': 7, 'banana': 9}
# {'apple': 3, 'pen': 5, 'orange': 7}

# %%
ppap = {'apple': 3, 'pen': 5, 'orange': 7}
ks = ppap.keys()
vs = ppap.values()
itms = ppap.items()
print(list(ks))
print(list(vs))
print(list(itms))
ppap['kiwi'] = 9
print(list(ks))
print(list(vs))
print(list(itms))
# Out:
# ['apple', 'pen', 'orange']
# [3, 5, 7]
# [('apple', 3), ('pen', 5), ('orange', 7)]
# ['apple', 'pen', 'orange', 'kiwi']
# [3, 5, 7, 9]
# [('apple', 3), ('pen', 5), ('orange', 7), ('kiwi', 9)]
