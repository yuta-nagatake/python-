# %% [markdown]
# <a href="https://colab.research.google.com/github/yuta-nagatake/python-/blob/main/4_1_%E3%83%95%E3%82%A1%E3%82%A4%E3%83%AB%E5%85%A5%E5%87%BA%E5%8A%9B%E3%81%AE%E5%9F%BA%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f = open('sample_data/README.md', 'r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4336/3326299884.py in <cell line: 0>()
# ----> 1 f = open('sample.txt', 'r')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample.txt'

# %%
f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4336/4000743260.py in <cell line: 0>()
# ----> 1 f.close()
#
# NameError: name 'f' is not defined

# %%
#'r' | 読み込み 'w' | 書き込み 'a' | 追記

# %%
f = open('sample.txt', 'r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4336/3326299884.py in <cell line: 0>()
# ----> 1 f = open('sample.txt', 'r')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample.txt'

# %%
f.readline()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4336/3005578867.py in <cell line: 0>()
# ----> 1 f.readline()
#
# NameError: name 'f' is not defined

# %%
#文字列の末尾にある改行文字の削除
'あいうえお \n'.rstrip()
# Out:
# 'あいうえお'

# %%
#削除する空白文字を改行文字 '\n' に限定したい場合
'あいうえお \n\n'.rstrip('\n')
# Out:
# 'あいうえお '
