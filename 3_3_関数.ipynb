# %% [markdown]
# <a href="https://colab.research.google.com/github/yuta-nagatake/python-/blob/main/3_3_%E9%96%A2%E6%95%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greeting():
  print("hello")
greeting()
# Out:
# hello

# %%
#def 関数名(引数):
   # 関数本体

# %%
def greeting(greeting_local):
    print(greeting_local)

# %%
greeting('Hello')
# Out:
# Hello

# %%
def average(nums):
  return sum(nums)/len(nums)
average([1,3,5,7,9])
# Out:
# 5.0

# %%
greeting_gobal="hello"

def greeting():
  print(greeting_gobal)

greeting()

greeting_gobal
# Out:
# hello
# 'hello'

# %%
#文字列と数値を引数として受け取る関数greeting
def greeting(en, number, name):
    print(en*number+','+name)

#関数greetingに引数の変数名とその値の組みを渡して呼び出し
greeting(en='Hello', name='Japan', number=2)
# Out:
# HelloHello,Japan

# %%
#位置引数とキーワード引数を組み合わせた関数greetingの呼び出し
greeting('Hello', name='Japan', number=2)
# Out:
# HelloHello,Japan
