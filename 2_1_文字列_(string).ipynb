# %% [markdown]
# <a href="https://colab.research.google.com/github/yuta-nagatake/python-/blob/main/2_1_%E6%96%87%E5%AD%97%E5%88%97_(string).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
word1 = 'hello'
word1
# Out:
# 'hello'

# %%
word2 = 'Hello'
word2
# Out:
# 'Hello'

# %%
#str は文字列のデータ型
type(word1)
# Out:
# str

# %%
type(word2)
# Out:
# str

# %%
word3 = str(123)
word3
# Out:
# '123'

# %%
i = int('123')
i
# Out:
# 123

# %%
f = float('123.4')
f
# Out:
# 123.4

# %%
len(word1)
# Out:
# 5

# %%
'hello'[2]
# Out:
# 'l'

# %%
word1 = 'hello'
word1[2]
# Out:
# 'l'

# %%
word1 = 'hello'
word1[0] = 'H'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_7109/1689567903.py in <cell line: 0>()
#       1 word1 = 'hello'
# ----> 2 word1[0] = 'H'
#
# TypeError: 'str' object does not support item assignment

# %%
word1[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_7109/521024611.py in <cell line: 0>()
# ----> 1 word1[100]
#
# IndexError: string index out of range

# %%
word1[-1]
# Out:
# 'o'

# %%
digits1='0123456789'
digits1[1:4]
# Out:
# '123'

# %%
digits1[0:3]
# Out:
# '012'

# %%
digits1[:3]
# Out:
# '012'

# %%
digits1[3:]
# Out:
# '3456789'

# %%
digits1[-4:-1]
# Out:
# '678'

# %%
digits1[3:9:2]
# Out:
# '357'

# %%
digits1[8:4:-1]
# Out:
# '8765'

# %%
price = '2,980円'
price.replace(',', '')
# Out:
# '2980円'

# %%
#文字列の検索
'lo' in 'hello'
# Out:
# True

# %%
'z' in 'hello'
# Out:
# False

# %%
word1 =  'hello'
substr1 = 'lo'
substr1 in word1
# Out:
# True

# %%
substr2 = 'z'
substr2 in word1
# Out:
# False

# %%
#not in 演算子は、in 演算子の逆
word1 =  'hello'
substr2 = 'z'
substr2 not in word1
# Out:
# True

# %%
escaped1 = 'This is \'MINE\''
escaped1
# Out:
# "This is 'MINE'"

# %%
doublequated = "This is 'MINE'"
doublequated
# Out:
# "This is 'MINE'"

# %%
escaped2 = "時は金なり\n\"Time is money\"\nTime is \\"
print(escaped2)
# Out:
# 時は金なり
# "Time is money"
# Time is \

# %%
triple_single_quated = '''時は金なり
'Time is money'
Time is \\'''
print(triple_single_quated)
# Out:
# 時は金なり
# 'Time is money'
# Time is \

# %%
#文字列の連結
word1 = 'hello'
word2 = ' world'
text1 = word1 + word2
text1
# Out:
# 'hello world'

# %%
word1 = 'hello'
word1 * 3
# Out:
# 'hellohellohello'

# %%
word1 = 'hello'
word1.replace('l', '123')
# Out:
# 'he123123o'

# %%
word1
# Out:
# 'hello'

# %%
#検索
word1 = 'hello'
word1.index('lo')
# Out:
# 3

# %%
#練習
def remove_punctuations(str_engsentences):
    str1 = str_engsentences.replace('.', '') # 指定の文字を空文字に置換
    str1 = str1.replace(',', '')
    str1 = str1.replace(':', '')
    str1 = str1.replace(';', '')
    str1 = str1.replace('!', '')
    str1 = str1.replace('?', '')
    return str1

# %%
#数え上げ
word1 = 'hello'
word1.count('l')
# Out:
# 2

# %%
'aaaaaaa'.count('aa')
# Out:
# 3

# %%
#練習
def swap_colon(str1):
    #コロンの位置を取得する # findでもOK
    col_index = str1.index(':')
    #コロンの位置を基準に前半と後半の部分文字列を取得する
    str2, str3 = str1[:col_index], str1[col_index+1:]
    #部分文字列の順序を入れ替えて結合する
    str4 = str3 + ':' + str2
    return str4
#swap_colon('hello:world')

# %%
#大文字・小文字
upper_dna = 'DNA'
upper_dna.lower() # 全ての文字を小文字にする
# Out:
# 'dna'

# %%
upper_dna
# Out:
# 'DNA'

# %%
lower_text = 'hello world!'
lower_text.capitalize() # 先頭文字を大文字にする
# Out:
# 'Hello world!'

# %%
lower_text
# Out:
# 'hello world!'

# %%
lower_text.upper() #全ての文字を大文字にする
# Out:
# 'HELLO WORLD!'

# %%
lower_text
# Out:
# 'hello world!'

# %%
#文字列の比較演算
print('abc' == 'abc')
print('ab' == 'abc')
# Out:
# True
# False

# %%
print('abc' != 'abc')
print('ab' != 'abc')
# Out:
# False
# True

# %%
print('abc' <= 'abc')
print('abc' < 'abc')
print('abc' < 'abd')
print('ab' < 'abc')
# Out:
# True
# False
# True
# True

# %%
def func(str1):
    return str1.upper()

# %%
str2 = 'abc'
func(str2)
# Out:
# 'ABC'

# %%
str2 = 'abc'
func('str2')
# Out:
# 'STR2'

# %%
def func(str1):
    return str1.upper()
