# %% [markdown]
# <a href="https://colab.research.google.com/github/yuta-nagatake/python-/blob/main/4_2_%E3%82%A4%E3%83%86%E3%83%A9%E3%83%96%E3%83%AB%E3%81%A8%E3%82%A4%E3%83%86%E3%83%AC%E3%83%BC%E3%82%BF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lines = []
with open('sample.txt', 'r') as f:
    for line in f:
        lines.append(line)
lines
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_8267/2271715332.py in <cell line: 0>()
#       1 lines = []
# ----> 2 with open('sample.txt', 'r') as f:
#       3     for line in f:
#       4         lines.append(line)
#       5 lines
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample.txt'

# %%
with open('sample.txt', 'r') as f:
    print('---- 最初 ----')
    for line in f:
        print(line)
    print('---- もう一度 ----')
    for line in f:
        print(line)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_8267/3641383642.py in <cell line: 0>()
# ----> 1 with open('sample.txt', 'r') as f:
#       2     print('---- 最初 ----')
#       3     for line in f:
#       4         print(line)
#       5     print('---- もう一度 ----')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample.txt'

# %%
#for文によって繰り返すことができるオブジェクトのことを総称して、イテラブル (iterable)

# %%
it = iter([0,1,2])

# %%
it = iter([0,1,2])
next(it)
# Out:
# 0

# %%
next(it)
# Out:
# 1

# %%
next(it)
# Out:
# 2

# %%
for x in [0,1,2]:
    print(x)
# Out:
# 0
# 1
# 2

# %%
try:
    it = iter([0,1,2])
    while True:
        x = next(it)
        print(x)
except StopIteration:
    pass
# Out:
# 0
# 1
# 2

# %%
it = iter([0,1,2])
for x in it:
    print(x)
# Out:
# 0
# 1
# 2

# %%
it = iter([0,1,2])
it is iter(it)
# Out:
# True

# %%
#isは両辺が同一オブジェクトかどうかを調べる演算子

# %%
xs = [1,2,3]
for x in xs:
    print(x)
for x in xs:
    print(x)
# Out:
# 1
# 2
# 3
# 1
# 2
# 3

# %%
r = range(3)
for x in r:
    print(x)
for x in r:
    print(x)
# Out:
# 0
# 1
# 2
# 0
# 1
# 2

# %%
it=enumerate([10,20,30])

# %%
next(it)
# Out:
# (0, 10)

# %%
for x in it:
    print(x)
# Out:
# (1, 20)
# (2, 30)

# %%
for i, c in enumerate('ACDB'):
    print(i, '番目の文字 =', c)
# Out:
# 0 番目の文字 = A
# 1 番目の文字 = C
# 2 番目の文字 = D
# 3 番目の文字 = B
